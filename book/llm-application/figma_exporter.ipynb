# %%
import os
import requests

# 환경변수에서 Figma 토큰 읽기
figma_access_token = os.getenv('FIGMA_YEOGI_ACCESS_TOKEN')

# Figma 파일 키 (예시: 'zfAZmC5DGzaXQzddryBvcV')
file_key = 'zfDKmK5WYzaXQzddryBvcV'

# API 호출 URL
url = f'https://api.figma.com/v1/files/{file_key}'

# HTTP 헤더에 API 토큰 추가
headers = {
    'X-Figma-Token': figma_access_token
}

# Figma API 요청 보내기
response = requests.get(url, headers=headers)

# 결과 확인
if response.status_code == 200:
    # data = response.json()  # 응답 데이터를 JSON 형식으로 변환
    # print(data)  # JSON 데이터 출력
    # JSON 응답에서 일부만 출력
    # data = response.json()
    print(data.keys())  # 필요한 데이터의 키만 출력
    print(data['document']['children'][0])  # 첫 번째 디자인 요소만 출력
    children_count = len(data['document']['children']) # Figma API로부터 받은 응답 데이터의 children 개수 확인
    print(f"Children의 개수: {children_count}")
else:
    print(f"Error: {response.status_code} - {response.text}")
# Out:
# dict_keys(['document', 'components', 'componentSets', 'schemaVersion', 'styles', 'name', 'lastModified', 'thumbnailUrl', 'version', 'role', 'editorType', 'linkAccess'])
# ...

# %%
# mongodb 연결하기
# mongodb client 설치하기
# !pip install pymongo
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 889.5/889.5 kB 30.8 MB/s eta 0:00:00
# ...

# %%
# mongodb 연결하기

from pymongo import MongoClient

# MongoDB 서버 URL과 데이터베이스 이름
url = 'mongodb://root:root1234@localhost:27017'
dbName = 'llm'

# MongoDB 클라이언트 생성 및 접속
client = MongoClient(url)

# 데이터베이스 선택
db = client[dbName]

# 연결 확인 (데이터베이스 목록 출력)
print("데이터베이스 목록:", client.list_database_names())

# 원하는 컬렉션 접근 (예: 'collection_name' 컬렉션)
collection = db['collection_name']

# 컬렉션에서 모든 데이터 조회 예시
documents = collection.find()
for doc in documents:
    print(doc)
# Out:
# 데이터베이스 목록: ['admin', 'config', 'local', 'springboot']
